# %% [markdown]
# ## Data wrangling code written by Jasmine Simmons
# ### Reading data in from github in .CSV and .XLSX file formats

# %%
import pandas as pd

# %%
#File names and datasets 
#YPCCC_2014_State.csv - Yale Study conducted in 2014 w/ population sentiments of climate change
#Carbon_dioxide_emission_by_state.xlsx - Carbon Dioxide per state from years 2005-2016

# %% [markdown]
# ## Read in data about population sentiment per state in 2014

# %%
df_YPCCC_2014_State = pd.read_csv("Datasets/YPCCC_2014_State.csv")
df_YPCCC_2014_State
# Out:
#    Statecode             Statename  TotalPop  taxdividend_PredPop  \
# 0         AK                Alaska    447543               185343
# 1         AL               Alabama   3166424              1291286
# 2         AR              Arkansas   1921039               815522
# 3         AZ               Arizona   4149955              1747013
# 4         CA            California  24117317             11341411
# 5         CO              Colorado   3328869              1458277
# 6         CT           Connecticut   2431340              1094904
# 7         DC  District of Columbia    417432               224318
# 8         DE              Delaware    603331               267427
# 9         FL               Florida  13127624              5615583
# 10        GA               Georgia   6242508              2670701
# 11        HI                Hawaii    928132               473519
# 12        IA                  Iowa   2013629               904017
# 13        ID                 Idaho    986172               432712
# 14        IL              Illinois   8459947              4104824
# 15        IN               Indiana   4229138              1765011
# 16        KS                Kansas   1838079               786508
# 17        KY              Kentucky   2902296              1146510
# 18        LA             Louisiana   2940298              1202717
# 19        MA         Massachusetts   4465898              1918228
# 20        MD              Maryland   3875282              1911533
# 21        ME                 Maine    938624               365252
# 22        MI              Michigan   6578519              3020142
# 23        MN             Minnesota   3525850              1525732
# 24        MO              Missouri   3973614              1721206
# 25        MS           Mississippi   1904849               842021
# 26        MT               Montana    671337               304318
# 27        NC        North Carolina   6324119              2705855
# 28        ND          North Dakota    442789               186006
# 29        NE              Nebraska   1184668               512591
# 30        NH         New Hampshire    907338               390964
# 31        NJ            New Jersey   5969516              2920587
# 32        NM            New Mexico   1333926               589023
# 33        NV                Nevada   1791029               830080
# 34        NY              New York  13101982              6787700
# 35        OH                  Ohio   7715893              3351575
# 36        OK              Oklahoma   2438321               941155
# 37        OR                Oregon   2612044              1153064
# 38        PA          Pennsylvania   8658872              4024797
# 39        RI          Rhode Island    709683               307677
# 40        SC        South Carolina   3075655              1370346
# 41        SD          South Dakota    531773               240517
# 42        TN             Tennessee   4250890              1750087
# 43        TX                 Texas  15765048              6734894
# 44        UT                  Utah   1578143               648543
# 45        VA              Virginia   5356571              2502230
# 46        VT               Vermont    431581               186722
# 47        WA            Washington   4507469              1991240
# 48        WI             Wisconsin   3800291              1742837
# 49        WV         West Virginia   1292274               508497
# 50        WY               Wyoming    371096               149001
#
#     taxdividend  taxdividendOppose_PredPop  taxdividendOppose  \
# 0            41                     117345                 26
# 1            41                     818043                 26
# 2            42                     456592                 24
# 3            42                    1009016                 24
# 4            47                    5524982                 23
# 5            44                     874243                 26
# 6            45                     637841                 26
# 7            54                      90260                 22
# 8            44                     161161                 27
# 9            43                    3262938                 25
# 10           43                    1479901                 24
# 11           51                     202455                 22
# 12           45                     527919                 26
# 13           44                     218442                 22
# 14           49                    1956770                 23
# 15           42                    1212738                 29
# 16           43                     482150                 26
# 17           40                     803164                 28
# 18           41                     769914                 26
# 19           43                    1215482                 27
# 20           49                     843148                 22
# 21           39                     288064                 31
# 22           46                    1693466                 26
# 23           43                     989618                 28
# 24           43                    1030364                 26
# 25           44                     417432                 22
# 26           45                     169609                 25
# 27           43                    1584150                 25
# 28           42                     137472                 31
# 29           43                     300550                 25
# 30           43                     252473                 28
# 31           49                    1251521                 21
# 32           44                     361876                 27
# 33           46                     421999                 24
# 34           52                    2349768                 18
# 35           43                    2053164                 27
# 36           39                     653821                 27
# 37           44                     645968                 25
# 38           46                    2042589                 24
# 39           43                     196924                 28
# 40           45                     712082                 23
# 41           45                     125057                 24
# 42           41                    1074215                 25
# 43           43                    3786173                 24
# 44           41                     392522                 25
# 45           47                    1236222                 23
# 46           43                     124044                 29
# 47           44                    1131384                 25
# 48           46                     976672                 26
# 49           39                     392879                 30
# 50           40                     106315                 29
#
#     CO2limits_PredPop  CO2limits  CO2limitsOppose_PredPop      ...       \
# 0              212898         48                   241910      ...
# 1             1673423         53                  1488482      ...
# 2             1124082         59                   804671      ...
# 3             2656998         64                  1463282      ...
# 4            17401401         72                  6205916      ...
# 5             2204350         66                  1092005      ...
# 6             1695497         70                   680980      ...
# 7              334540         80                    69463      ...
# 8              388377         64                   200273      ...
# 9             8141092         62                  4733603      ...
# 10            3743382         60                  2419029      ...
# 11             709699         76                   197662      ...
# 12            1317437         65                   683284      ...
# 13             623324         63                   369250      ...
# 14            5935476         70                  2400117      ...
# 15            2386497         56                  1825085      ...
# 16            1108020         60                   737343      ...
# 17            1531042         53                  1360907      ...
# 18            1473138         50                  1492371      ...
# 19            3055781         68                  1303130      ...
# 20            2718376         70                  1079507      ...
# 21             582395         62                   334244      ...
# 22            4413914         67                  2076409      ...
# 23            2255018         64                  1246105      ...
# 24            2533144         64                  1422369      ...
# 25            1174759         62                   712965      ...
# 26             410113         61                   264025      ...
# 27            3868949         61                  2357882      ...
# 28             212405         48                   237220      ...
# 29             728035         61                   461209      ...
# 30             597793         66                   294336      ...
# 31            4347689         73                  1550473      ...
# 32             826435         62                   487620      ...
# 33            1229549         69                   537357      ...
# 34            9921394         76                  3015382      ...
# 35            4822466         63                  2827999      ...
# 36            1276074         52                  1182747      ...
# 37            1799501         69                   772123      ...
# 38            5772659         67                  2821263      ...
# 39             492763         69                   197873      ...
# 40            1840507         60                  1210281      ...
# 41             349862         66                   182259      ...
# 42            2508126         59                  1706083      ...
# 43            9615750         61                  6054867      ...
# 44             917152         58                   675122      ...
# 45            3519462         66                  1763724      ...
# 46             299135         69                   120821      ...
# 47            3115443         69                  1319565      ...
# 48            2513044         66                  1246884      ...
# 49             555820         43                   742282      ...
# 50             159637         43                   220698      ...
#
#     devharmOppose_PredPop  devharmOppose  futuregen_PredPop  futuregen  \
# 0                  176049             39             245072         55
# 1                 1171971             37            1693632         53
# 2                  716456             37            1058621         55
# 3                 1431995             35            2512113         61
# 4                 6559723             27           16880034         70
# 5                 1139199             34            2124109         64
# 6                  788063             32            1626190         67
# 7                   72908             17             334035         80
# 8                  189315             31             393878         65
# 9                 4455035             34            8120955         62
# 10                2084454             33            3663372         59
# 11                 234208             25             696964         75
# 12                 752448             37            1266192         63
# 13                 398871             40             528940         54
# 14                2636381             31            5508685         65
# 15                1625949             38            2403652         57
# 16                 734305             40            1061124         58
# 17                1172095             40            1593752         55
# 18                1084012             37            1585424         54
# 19                1425735             32            3075253         69
# 20                1093691             28            2564690         66
# 21                 342489             36             613508         65
# 22                2339840             36            4051377         62
# 23                1328951             38            2269352         64
# 24                1449889             36            2429291         61
# 25                 641905             34            1073257         56
# 26                 261265             39             383635         57
# 27                2113604             33            3791595         60
# 28                 195289             44             244110         55
# 29                 475686             40             684280         58
# 30                 346231             38             569297         63
# 31                1681436             28            3983109         67
# 32                 408942             31             865220         65
# 33                 570931             32            1139900         64
# 34                3525809             27            9076595         69
# 35                2917235             38            4523520         59
# 36                 992213             41            1319431         54
# 37                 841747             32            1745826         67
# 38                3066964             35            5381439         62
# 39                 232978             33             483011         68
# 40                1070797             35            1719701         56
# 41                 208283             39             315564         59
# 42                1575047             37            2407798         57
# 43                5164353             33            9591063         61
# 44                 646377             41             847589         54
# 45                1743711             33            3286784         61
# 46                 143550             33             301484         70
# 47                1480103             33            3045914         68
# 48                1375242             36            2318799         61
# 49                 548879             42             658977         51
# 50                 166085             45             177146         48
#
#     futuregenOppose_PredPop  futuregenOppose  timing_PredPop  timing  \
# 0                    146537               33          181461      41
# 1                    949324               30         1256671      40
# 2                    568292               30          749958      39
# 3                   1071469               26         1835668      44
# 4                   4528428               19        11651580      48
# 5                    805908               24         1451221      44
# 6                    525690               22         1066467      44
# 7                     41147               10          237400      57
# 8                    129030               21          267231      44
# 9                   3121361               24         5879498      45
# 10                  1518639               24         2775240      44
# 11                   152360               16          464231      50
# 12                   536332               27          781697      39
# 13                   307673               31          377494      38
# 14                  1763746               21         3720316      44
# 15                  1204441               28         1645065      39
# 16                   558644               30          701514      38
# 17                   912916               31         1119560      39
# 18                   868290               30         1188181      40
# 19                   952433               21         2072875      46
# 20                   735744               19         1780755      46
# 21                   237207               25          406426      43
# 22                  1587619               24         2650085      40
# 23                   930078               26         1429234      41
# 24                  1071432               27         1580802      40
# 25                   486564               26          793357      42
# 26                   196812               29          253384      38
# 27                  1552722               25         2719283      43
# 28                   152202               34          154891      35
# 29                   360086               30          449486      38
# 30                   237944               26          361330      40
# 31                  1216508               20         2690077      45
# 32                   298439               22          603404      45
# 33                   405108               23          777445      43
# 34                  2351582               18         6295195      48
# 35                  2059890               27         3054430      40
# 36                   800839               33          967715      40
# 37                   600658               23         1162208      44
# 38                  2156239               25         3525776      41
# 39                   152572               21          313624      44
# 40                   803083               26         1255593      41
# 41                   154155               29          202214      38
# 42                  1207204               28         1709154      40
# 43                  3947452               25         6983454      44
# 44                   510538               32          624162      40
# 45                  1246895               23         2279792      43
# 46                    92466               21          191468      44
# 47                  1014955               23         2026376      45
# 48                   962280               25         1498836      39
# 49                   440234               34          465700      36
# 50                   140487               38          131444      35
#
#     timingOppose_PredPop  timingOppose
# 0                 263150            59
# 1                1890952            60
# 2                1159820            60
# 3                2298091            55
# 4               12291289            51
# 5                1858348            56
# 6                1347825            55
# 7                 172235            41
# 8                 330916            55
# 9                7175321            55
# 10               3421622            55
# 11                455422            49
# 12               1218103            60
# 13                604986            61
# 14               4655275            55
# 15               2556730            60
# 16               1129148            61
# 17               1766779            61
# 18               1728854            59
# 19               2356926            53
# 20               2052127            53
# 21                526507            56
# 22               3880787            59
# 23               2074316            59
# 24               2367394            60
# 25               1097050            58
# 26                413339            62
# 27               3563836            56
# 28                285069            64
# 29                730182            62
# 30                541477            60
# 31               3226038            54
# 32                722907            54
# 33               1001657            56
# 34               6631947            51
# 35               4611441            60
# 36               1463883            60
# 37               1431341            55
# 38               5055908            58
# 39                391028            55
# 40               1797887            58
# 41                326695            61
# 42               2519992            59
# 43               8711815            55
# 44                949735            60
# 45               3035156            57
# 46                236289            55
# 47               2451223            54
# 48               2274022            60
# 49                817406            63
# 50                237887            64
#
# [51 rows x 59 columns]

# %% [markdown]
# ### Specify which columns we would like to keep in the dataframe for our analysis:

# %%
list(df_YPCCC_2014_State.columns)
# Out:
# ['Statecode',
#  'Statename',
#  'TotalPop',
#  'taxdividend_PredPop',
#  'taxdividend',
#  'taxdividendOppose_PredPop',
#  'taxdividendOppose',
#  'CO2limits_PredPop',
#  'CO2limits',
#  'CO2limitsOppose_PredPop',
#  'CO2limitsOppose',
#  'regulate_PredPop',
#  'regulate',
#  'regulateOppose_PredPop',
#  'regulateOppose',
#  'supportRPS_PredPop',
#  'supportRPS',
#  'supportRPSOppose_PredPop',
#  'supportRPSOppose',
#  'fundrenewables_PredPop',
#  'fundrenewables',
#  'fundrenewablesOppose_PredPop',
#  'fundrenewablesOppose',
#  'happening_PredPop',
#  'happening',
#  'happeningOppose_PredPop',
#  'happeningOppose',
#  'human_PredPop',
#  'human',
#  'humanOppose_PredPop',
#  'humanOppose',
#  'consensus_PredPop',
#  'consensus',
#  'consensusOppose_PredPop',
#  'consensusOppose',
#  'worried_PredPop',
#  'worried',
#  'worriedOppose_PredPop',
#  'worriedOppose',
#  'personal_PredPop',
#  'personal',
#  'personalOppose_PredPop',
#  'personalOppose',
#  'harmUS_PredPop',
#  'harmUS',
#  'harmUSOppose_PredPop',
#  'harmUSOppose',
#  'devharm_PredPop',
#  'devharm',
#  'devharmOppose_PredPop',
#  'devharmOppose',
#  'futuregen_PredPop',
#  'futuregen',
#  'futuregenOppose_PredPop',
#  'futuregenOppose',
#  'timing_PredPop',
#  'timing',
#  'timingOppose_PredPop',
#  'timingOppose']

# %%
columns_keep = ['Statecode', 'Statename', 'TotalPop', 'happening', 'human', 'worried', 'personal', 'CO2limits', 'regulate', 'fundrenewables']
df_YPCCC_2014_State_new = df_YPCCC_2014_State[columns_keep]
df_YPCCC_2014_State_new
# Out:
#    Statecode             Statename  TotalPop  happening  human  worried  \
# 0         AK                Alaska    447543         62     45       48
# 1         AL               Alabama   3166424         56     43       46
# 2         AR              Arkansas   1921039         57     44       47
# 3         AZ               Arizona   4149955         64     49       54
# 4         CA            California  24117317         70     55       62
# 5         CO              Colorado   3328869         66     50       55
# 6         CT           Connecticut   2431340         66     51       56
# 7         DC  District of Columbia    417432         81     61       71
# 8         DE              Delaware    603331         65     50       55
# 9         FL               Florida  13127624         64     50       54
# 10        GA               Georgia   6242508         63     48       52
# 11        HI                Hawaii    928132         75     58       66
# 12        IA                  Iowa   2013629         60     47       50
# 13        ID                 Idaho    986172         58     44       48
# 14        IL              Illinois   8459947         67     51       56
# 15        IN               Indiana   4229138         58     46       46
# 16        KS                Kansas   1838079         58     45       48
# 17        KY              Kentucky   2902296         56     44       46
# 18        LA             Louisiana   2940298         57     44       46
# 19        MA         Massachusetts   4465898         69     52       58
# 20        MD              Maryland   3875282         68     52       58
# 21        ME                 Maine    938624         64     49       53
# 22        MI              Michigan   6578519         61     48       51
# 23        MN             Minnesota   3525850         63     48       52
# 24        MO              Missouri   3973614         60     46       50
# 25        MS           Mississippi   1904849         59     45       50
# 26        MT               Montana    671337         60     46       48
# 27        NC        North Carolina   6324119         62     48       52
# 28        ND          North Dakota    442789         56     43       43
# 29        NE              Nebraska   1184668         58     45       48
# 30        NH         New Hampshire    907338         61     48       51
# 31        NJ            New Jersey   5969516         68     52       59
# 32        NM            New Mexico   1333926         66     52       56
# 33        NV                Nevada   1791029         64     50       55
# 34        NY              New York  13101982         72     54       63
# 35        OH                  Ohio   7715893         59     47       48
# 36        OK              Oklahoma   2438321         57     44       46
# 37        OR                Oregon   2612044         67     51       57
# 38        PA          Pennsylvania   8658872         62     48       53
# 39        RI          Rhode Island    709683         66     51       56
# 40        SC        South Carolina   3075655         59     45       49
# 41        SD          South Dakota    531773         59     46       50
# 42        TN             Tennessee   4250890         58     45       48
# 43        TX                 Texas  15765048         63     49       54
# 44        UT                  Utah   1578143         60     45       48
# 45        VA              Virginia   5356571         64     49       54
# 46        VT               Vermont    431581         68     52       57
# 47        WA            Washington   4507469         68     51       58
# 48        WI             Wisconsin   3800291         61     48       50
# 49        WV         West Virginia   1292274         54     43       42
# 50        WY               Wyoming    371096         55     42       41
#
#     personal  CO2limits  regulate  fundrenewables
# 0         29         48        67              76
# 1         31         53        69              73
# 2         31         59        71              73
# 3         38         64        74              76
# 4         42         72        79              79
# 5         36         66        76              78
# 6         37         70        78              79
# 7         47         80        86              86
# 8         36         64        77              79
# 9         38         62        75              77
# 10        36         60        74              75
# 11        43         76        81              83
# 12        31         65        75              78
# 13        32         63        72              74
# 14        36         70        78              80
# 15        30         56        72              76
# 16        31         60        71              76
# 17        30         53        70              75
# 18        31         50        68              73
# 19        37         68        79              80
# 20        38         70        79              80
# 21        34         62        76              78
# 22        33         67        76              78
# 23        32         64        75              79
# 24        32         64        74              76
# 25        35         62        73              74
# 26        29         61        72              78
# 27        35         61        75              76
# 28        24         48        67              77
# 29        30         61        71              76
# 30        32         66        76              78
# 31        38         73        78              79
# 32        38         62        75              78
# 33        37         69        76              78
# 34        40         76        80              80
# 35        32         63        74              77
# 36        32         52        68              73
# 37        36         69        78              78
# 38        33         67        76              77
# 39        36         69        79              79
# 40        33         60        73              76
# 41        31         66        73              76
# 42        33         59        72              74
# 43        38         61        73              75
# 44        32         58        70              74
# 45        35         66        76              79
# 46        35         69        79              81
# 47        37         69        78              79
# 48        32         66        76              79
# 49        25         43        67              75
# 50        25         43        64              74

# %% [markdown]
# ## Read in data about carbon dioxide emissions released per state for same year, 2014:

# %%
df_CO2_state = pd.read_excel("Datasets/Carbon_dioxide_emission_by_state.xlsx")
df_CO2_state
# Out:
#    Table 2. State energy-related carbon dioxide emissions by year, adjusted (2005─2016)  \
# 0               million metric tons of carbon dioxide
# 1                                                 NaN
# 2                                                 NaN
# 3                                               State
# 4                                             Alabama
# 5                                              Alaska
# 6                                             Arizona
# 7                                            Arkansas
# 8                                          California
# 9                                            Colorado
# 10                                        Connecticut
# 11                                           Delaware
# 12                               District of Columbia
# 13                                            Florida
# 14                                            Georgia
# 15                                             Hawaii
# 16                                              Idaho
# 17                                           Illinois
# 18                                            Indiana
# 19                                               Iowa
# 20                                             Kansas
# 21                                           Kentucky
# 22                                          Louisiana
# 23                                              Maine
# 24                                           Maryland
# 25                                      Massachusetts
# 26                                           Michigan
# 27                                          Minnesota
# 28                                        Mississippi
# 29                                           Missouri
# 30                                            Montana
# 31                                           Nebraska
# 32                                             Nevada
# 33                                      New Hampshire
# 34                                         New Jersey
# 35                                         New Mexico
# 36                                           New York
# 37                                     North Carolina
# 38                                       North Dakota
# 39                                               Ohio
# 40                                           Oklahoma
# 41                                             Oregon
# 42                                       Pennsylvania
# 43                                       Rhode Island
# 44                                     South Carolina
# 45                                       South Dakota
# 46                                          Tennessee
# 47                                              Texas
# 48                                               Utah
# 49                                            Vermont
# 50                                           Virginia
# 51                                         Washington
# 52                                      West Virginia
# 53                                          Wisconsin
# 54                                            Wyoming
# 55                                      United States
# 56  Source:  United States total, Monthly Energy R...
# 57  The state values that appear in this table hav...
# 58  Note:  The District of Columbia is included in...
# 59  Source:  EIA, State Energy Data System, and EI...
#
#      Unnamed: 1   Unnamed: 2   Unnamed: 3   Unnamed: 4   Unnamed: 5  \
# 0           NaN          NaN          NaN          NaN          NaN
# 1           NaN          NaN          NaN          NaN          NaN
# 2           NaN          NaN          NaN          NaN          NaN
# 3   2005.000000  2006.000000  2007.000000  2008.000000  2009.000000
# 4    145.717386   148.040103   149.574946   141.803359   121.948916
# 5     49.017593    46.644660    44.870695    40.253261    38.588620
# 6     98.289736   101.468835   103.357057   103.841365    94.836579
# 7     61.080761    62.918003    64.213320    65.141909    62.419653
# 8    390.133567   398.302410   403.127766   387.428138   373.800883
# 9     96.795597    97.700271   100.254100    98.388137    94.152034
# 10    44.806009    41.662092    40.835317    38.253591    36.484331
# 11    17.056965    15.971158    16.783208    15.862116    12.165965
# 12     3.984124     3.229448     3.425608     3.130070     3.223236
# 13   264.996379   263.157296   260.578250   242.271887   227.725149
# 14   187.410094   184.642255   187.141716   174.538665   164.572672
# 15    23.302532    23.545096    24.344604    19.561525    19.144623
# 16    16.068040    16.084333    16.585384    15.809884    15.422682
# 17   246.032194   237.519885   245.096245   243.745177   228.275642
# 18   237.388699   234.927290   234.556329   230.303233   207.027340
# 19    79.965480    81.214595    86.473833    90.436951    85.270884
# 20    72.774211    72.972614    80.811653    75.390515    73.559842
# 21   152.068601   154.352161   154.701423   152.447750   141.903827
# 18   188.400189   182.854052    -0.229727    -54.5346
# 19    76.821309    73.534941   -0.0804164    -6.43054
# 20    64.746303    62.404283    -0.142495    -10.3699
# 21   129.835097   124.602368    -0.180617    -27.4662
# 22   206.475041   210.280227   0.00702284     1.46647
# 23    17.072814    16.552383    -0.296051    -6.96123
# 24    60.235859    57.874769    -0.305805    -25.4948
# 25    66.461156    64.543938    -0.248334    -21.3239
# 26   163.753556   152.602043    -0.211855    -41.0197
# 27    88.898181    89.746240    -0.129199    -13.3155
# 28    66.014615    69.296656    0.0669587     4.34882
# 29   123.928726   118.326189    -0.175503    -25.1871
# 30    32.326060    30.626818    -0.136824    -4.85471
# 31    51.335770    48.821379    0.0994174     4.41479
# 32    35.711071    36.852838    -0.273016    -13.8399
# 33    15.395576    13.828610    -0.360334    -7.78987
# 34   113.012375   111.444349    -0.146191    -19.0817
# 35    50.736382    48.653352    -0.189253    -11.3571
# 36   169.864794   164.556233    -0.226992    -48.3216
# 37   122.600732   121.216686    -0.225903    -35.3744
# 38    57.957509    54.581890    0.0274343     1.45743
# 39   215.383985   207.409731    -0.246455    -67.8357
# 40   101.956375    97.444457   -0.0984084     -10.636
# 41    38.615288    38.177567   -0.0865621     -3.6179
# 42   232.712763   218.605364    -0.228434    -64.7214
# 43    11.039859     9.803139    -0.139391     -1.5878
# 44    73.552626    72.102252    -0.175438    -15.3409
# 45    14.437146    15.077556     0.114946     1.55443
# 46   101.232349   103.639952    -0.185394    -23.5871
# 47   626.477676   657.420430    0.0749629     45.8455
# 48    64.283097    59.084949    -0.129387    -8.78094
# 49     6.240317     5.987708    -0.135061   -0.934987
# 50   104.520770   104.811559     -0.20044     -26.275
# 51    74.360352    79.290691    0.0295853     2.27843
# 52    93.260686    95.072612    -0.164903    -18.7736
# 53   101.111249    96.135275    -0.144109    -16.1866
# 54    64.185094    61.006928   -0.0471663    -3.01991
# 55  5274.115412  5189.397770     -0.13389    -802.219
# 56          NaN          NaN          NaN         NaN
# 57          NaN          NaN          NaN         NaN
# 58          NaN          NaN          NaN         NaN
# 59          NaN          NaN          NaN         NaN

# %% [markdown]
# ### Clean up dataframe: Drop NaN values and rename columns with proper years for 2012, 2014, 2016 data:

# %%
##Renaming the columns to be the years:
col_years = ['State']
for year in list(range(2005, 2017)):
    col_years.append(str(year))

col_years.append('Percent Change')
col_years.append('Absolute')

df_CO2_state.columns=col_years
print(df_CO2_state.columns)
# Out:
# Index(['State', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012',
#        '2013', '2014', '2015', '2016', 'Percent Change', 'Absolute'],
#       dtype='object')

# %%
#Deleting unnecessary rows from beginning, renaming index to be the state names:
new_df_CO2_state = df_CO2_state.iloc[4:55]
new_df_CO2_state = new_df_CO2_state.set_index('State')
new_df_CO2_state
# Out:
#                             2005        2006        2007        2008  \
# State
# Alabama               145.717386  148.040103  149.574946  141.803359
# Alaska                 49.017593   46.644660   44.870695   40.253261
# Arizona                98.289736  101.468835  103.357057  103.841365
# Arkansas               61.080761   62.918003   64.213320   65.141909
# California            390.133567  398.302410  403.127766  387.428138
# Colorado               96.795597   97.700271  100.254100   98.388137
# Oklahoma                 -0.0984084   -10.636
# Oregon                   -0.0865621   -3.6179
# Pennsylvania              -0.228434  -64.7214
# Rhode Island              -0.139391   -1.5878
# South Carolina            -0.175438  -15.3409
# South Dakota               0.114946   1.55443
# Tennessee                 -0.185394  -23.5871
# Texas                     0.0749629   45.8455
# Utah                      -0.129387  -8.78094
# Vermont                   -0.135061 -0.934987
# Virginia                   -0.20044   -26.275
# Washington                0.0295853   2.27843
# West Virginia             -0.164903  -18.7736
# Wisconsin                 -0.144109  -16.1866
# Wyoming                  -0.0471663  -3.01991

# %%
#Right now, only concerned with year 2014:
df_CO2_state_2014 = pd.DataFrame(new_df_CO2_state[:]['2014'])
df_CO2_state_2014.columns=(["CO2_Emissions_in_2014"])
df_CO2_state_2014
# Out:
#                       CO2_Emissions_in_2014
# State
# Alabama                          124.751678
# Alaska                            35.795496
# Arizona                           94.371266
# Arkansas                          69.892555
# California                       357.499077
# Colorado                          92.911068
# Connecticut                       35.606268
# Delaware                          12.910214
# District of Columbia               3.058483
# Florida                          230.652130
# Georgia                          141.399702
# Hawaii                            18.598966
# Idaho                             16.900937
# Illinois                         235.412072
# Indiana                          207.945714
# Iowa                              82.859688
# Kansas                            70.491055
# Kentucky                         139.326399
# Louisiana                        203.776138
# Maine                             16.862817
# Maryland                          62.184186
# Massachusetts                     64.589904
# Michigan                         163.567087
# Minnesota                         96.004094
# Mississippi                       64.719446
# Missouri                         133.327836
# Montana                           32.380830
# Nebraska                          52.848071
# Nevada                            37.690720
# New Hampshire                     15.203143
# New Jersey                       114.727829
# New Mexico                        50.622085
# New York                         171.968046
# North Carolina                   129.019427
# North Dakota                      59.358200
# Ohio                             234.356927
# Oklahoma                         105.865059
# Oregon                            38.527135
# Pennsylvania                     249.112237
# Rhode Island                      10.782673
# South Carolina                    75.185970
# South Dakota                      15.693404
# Tennessee                        104.983621
# Texas                            626.004217
# Utah                              65.948381
# Vermont                            5.978197
# Virginia                         105.422591
# Washington                        72.460264
# West Virginia                    101.249831
# Wisconsin                        102.365622
# Wyoming                           66.162416

# %% [markdown]
# ### Load in state party affiliation:

# %%
df_party_state = pd.read_csv("Datasets/State_Party_Affiliation_2014.csv")
df_party_state = df_party_state.set_index("State")
df_party_state.columns=["Republican", "No_lean", "Democrat", "Sample_Size"]
df_party_state.Republican = df_party_state.Republican.apply(lambda x: x.replace('%',''))
df_party_state.No_lean = df_party_state.No_lean.apply(lambda x: x.replace('%',''))
df_party_state.Democrat = df_party_state.Democrat.apply(lambda x: x.replace('%',''))
df_party_state
# Out:
#                      Republican No_lean Democrat Sample_Size
# State
# Alabama                      52      13       35         511
# Alaska                       39      29       32         310
# Arizona                      40      21       39         653
# Arkansas                     46      16       38         311
# California                   30      21       49       3,697
# Colorado                     41      17       42         504
# Connecticut                  32      18       50         377
# Delaware                     29      17       55         301
# District of Columbia         11      15       73         303
# Florida                      37      19       44       2,020
# Georgia                      41      18       41         968
# Hawaii                       28      20       51         312
# Idaho                        49      19       32         320
# Illinois                     33      19       48       1,326
# Indiana                      42      20       37         654
# Iowa                         41      19       40         330
# Kansas                       46      23       31         307
# Kentucky                     44      13       43         439
# Louisiana                    41      16       43         465
# Maine                        36      17       47         303
# Maryland                     31      14       55         644
# Massachusetts                27      17       56         704
# Michigan                     34      19       47         982
# Minnesota                    39      15       46         563
# Mississippi                  44      14       42         309
# Missouri                     41      18       42         642
# Montana                      49      21       30         312
# Nebraska                     47      17       36         312
# Nevada                       37      18       46         314
# New Hampshire                35      20       44         303
# New Jersey                   30      19       51         886
# New Mexico                   37      15       48         312
# New York                     28      19       53       1,966
# North Carolina               41      17       43       1,022
# North Dakota                 50      18       33         338
# Ohio                         42      18       40       1,132
# Oklahoma                     45      15       40         391
# Oregon                       32      21       47         419
# Pennsylvania                 39      15       46       1,366
# Rhode Island                 30      22       48         305
# South Carolina               43      18       39         495
# South Dakota                 53      10       37         305
# Tennessee                    48      15       36         661
# Texas                        39      21       40       2,535
# Utah                         54      16       30         315
# Vermont                      29      14       57         306
# Virginia                     43      18       39         882
# Washington                   33      23       44         714
# West Virginia                43      16       41         309
# Wisconsin                    42      16       42         600
# Wyoming                      57      18       25         316

# %%
#Create new dataframe where each state is either labelled "Democrat" or "Republican":
for state in df_party_state.loc['State']:
    if 


#Questions: 
#Do republican states release more CO2 than Democratic states?
#Are Republican states less concerned with climate change than Democratic states? 


#Create an increasing bar graph based on CO2 emissions - color code Republicans red and Democrats blue
# Out:
#   File "<ipython-input-135-c7f40a52995f>", line 3
#     if
#        ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### Create a dictionary to store state-CO2 key-value pairs.

# %%
import operator

states = df_party_state.index.values
CO2 = df_CO2_state_2014['CO2_Emissions_in_2014']
keys = states
values = CO2

CO2_states_dict = dict(zip(keys, values))
sorted_CO2_states_dict = sorted(CO2_states_dict.items(), key=operator.itemgetter(1))
sorted_CO2_states_dict
# Out:
# [('District of Columbia', 3.058482653904067),
#  ('Vermont', 5.978197315492187),
#  ('Rhode Island', 10.7826725141325),
#  ('Delaware', 12.91021354917304),
#  ('New Hampshire', 15.20314283129481),
#  ('South Dakota', 15.6934043101805),
#  ('Maine', 16.86281667172631),
#  ('Idaho', 16.90093667232123),
#  ('Hawaii', 18.59896623325539),
#  ('Montana', 32.38082999765135),
#  ('Connecticut', 35.60626767531578),
#  ('Alaska', 35.79549643329857),
#  ('Nevada', 37.69071959374811),
#  ('Oregon', 38.52713544709768),
#  ('New Mexico', 50.62208526130043),
#  ('Nebraska', 52.84807090631335),
#  ('North Dakota', 59.35820009729986),
#  ('Maryland', 62.18418619355862),
#  ('Massachusetts', 64.58990363092897),
#  ('Mississippi', 64.71944608223072),
#  ('Utah', 65.94838053103923),
#  ('Wyoming', 66.16241605336825),
#  ('Arkansas', 69.8925548268733),
#  ('Kansas', 70.49105475817697),
#  ('Washington', 72.46026415993808),
#  ('South Carolina', 75.18596985504142),
#  ('Iowa', 82.85968814074053),
#  ('Colorado', 92.91106792306537),
#  ('Arizona', 94.37126599947494),
#  ('Minnesota', 96.00409436619555),
#  ('West Virginia', 101.2498305145077),
#  ('Wisconsin', 102.3656215843109),
#  ('Tennessee', 104.9836211582722),
#  ('Virginia', 105.4225905355684),
#  ('Oklahoma', 105.8650588747374),
#  ('New Jersey', 114.7278293478581),
#  ('Alabama', 124.7516781708409),
#  ('North Carolina', 129.0194268281983),
#  ('Missouri', 133.3278356152263),
#  ('Kentucky', 139.3263992763261),
#  ('Georgia', 141.3997015112668),
#  ('Michigan', 163.5670870285041),
#  ('New York', 171.9680463924164),
#  ('Louisiana', 203.776138354388),
#  ('Indiana', 207.9457139722577),
#  ('Florida', 230.652129903842),
#  ('Ohio', 234.3569267220609),
#  ('Illinois', 235.4120724639861),
#  ('Pennsylvania', 249.1122365955579),
#  ('California', 357.4990774816918),
#  ('Texas', 626.004216984045)]

# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt

fig_size = plt.rcParams["figure.figsize"]

fig_size[0] = 12
fig_size[1] = 9
plt.rcParams["figure.figsize"] = fig_size

States = []
CO2 = []

for state, co2 in sorted_CO2_states_dict: 
    States.append(state)
    CO2.append(co2)

y_pos = np.arange(len(States))

plt.barh(y_pos, CO2, align='center', alpha=0.5)
plt.yticks(y_pos, States)
plt.ylabel('CO2 Emissions (million metric tonnes) in 2014')
plt.title('U.S. State CO2 Emissions in 2014')

plt.show()

# %%
#Now color code the graph based on the political affiliation of each state: 
state_party_dict = {}
for state in df_party_state.index.values:
    if float(df_party_state.at[state, 'Republican']) > float(df_party_state.at[state, 'Democrat']):
        state_party_dict[state] = 'Republican'
    else:
        state_party_dict[state] = 'Democrat'
        
#print(state_party_dict)
print(sorted_CO2_states_dict)
        
colors = []
sorted_states_by_CO2 = [state[0] for state in sorted_CO2_states_dict]

for state in sorted_states_by_CO2: 
    if state_party_dict[state] == 'Republican':
        colors.append('red')
    else:
        colors.append('blue')

print(colors)
# Out:
# [('District of Columbia', 3.058482653904067), ('Vermont', 5.978197315492187), ('Rhode Island', 10.7826725141325), ('Delaware', 12.91021354917304), ('New Hampshire', 15.20314283129481), ('South Dakota', 15.6934043101805), ('Maine', 16.86281667172631), ('Idaho', 16.90093667232123), ('Hawaii', 18.59896623325539), ('Montana', 32.38082999765135), ('Connecticut', 35.60626767531578), ('Alaska', 35.79549643329857), ('Nevada', 37.69071959374811), ('Oregon', 38.52713544709768), ('New Mexico', 50.62208526130043), ('Nebraska', 52.84807090631335), ('North Dakota', 59.35820009729986), ('Maryland', 62.18418619355862), ('Massachusetts', 64.58990363092897), ('Mississippi', 64.71944608223072), ('Utah', 65.94838053103923), ('Wyoming', 66.16241605336825), ('Arkansas', 69.8925548268733), ('Kansas', 70.49105475817697), ('Washington', 72.46026415993808), ('South Carolina', 75.18596985504142), ('Iowa', 82.85968814074053), ('Colorado', 92.91106792306537), ('Arizona', 94.37126599947494), ('Minnesota', 96.00409436619555), ('West Virginia', 101.2498305145077), ('Wisconsin', 102.3656215843109), ('Tennessee', 104.9836211582722), ('Virginia', 105.4225905355684), ('Oklahoma', 105.8650588747374), ('New Jersey', 114.7278293478581), ('Alabama', 124.7516781708409), ('North Carolina', 129.0194268281983), ('Missouri', 133.3278356152263), ('Kentucky', 139.3263992763261), ('Georgia', 141.3997015112668), ('Michigan', 163.5670870285041), ('New York', 171.9680463924164), ('Louisiana', 203.776138354388), ('Indiana', 207.9457139722577), ('Florida', 230.652129903842), ('Ohio', 234.3569267220609), ('Illinois', 235.4120724639861), ('Pennsylvania', 249.1122365955579), ('California', 357.4990774816918), ('Texas', 626.004216984045)]
# ['blue', 'blue', 'blue', 'blue', 'blue', 'red', 'blue', 'red', 'blue', 'red', 'blue', 'red', 'blue', 'blue', 'blue', 'red', 'red', 'blue', 'blue', 'red', 'red', 'red', 'red', 'red', 'blue', 'red', 'red', 'blue', 'red', 'blue', 'red', 'blue', 'red', 'red', 'red', 'blue', 'red', 'blue', 'blue', 'red', 'blue', 'blue', 'blue', 'blue', 'red', 'blue', 'red', 'blue', 'blue', 'blue', 'blue']

# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt

fig_size = plt.rcParams["figure.figsize"]

fig_size[0] = 12
fig_size[1] = 9
plt.rcParams["figure.figsize"] = fig_size

States = []
CO2 = []

for state, co2 in sorted_CO2_states_dict: 
    if state != "District of Columbia":
        States.append(state)
        CO2.append(co2)

y_pos = np.arange(len(States))

plt.barh(y_pos, CO2, align='center', alpha=0.5, color=colors)
plt.yticks(y_pos, States)
plt.ylabel('CO2 Emissions (million metric tonnes) in 2014')
plt.title('U.S. State CO2 Emissions in 2014')

plt.show()

# %% [markdown]
# ### Analysis: From the above graph, we see that there is no clear correlation between state political party affiliation and the amount of CO2 released by that state as there are democratic states with both the most and the least amount of CO2 released. However, we notice that the states with the largest amoutn of CO2 are also the largest states in terms of land area. Therefore, we will perform an analysis that looks at the amount of CO2 released per size of the state, by dividing CO2 emissions by the state's size in sq. miles.

# %%
#This graph shows us that there is no clear trend; however, we see that larger states appear to have more CO2. 
#Therefore, we need to look at CO2 amounts per either person/population density or per size of state 

df_state_size = pd.read_csv("Datasets/2014_State_Size_Population_Density.csv")
#df_state_size

df_state_area = df_state_size.drop(["Population", "Density (people per sq mi)"], axis = 1)
#df_state_area = df_state_area.set_index("State")
#new_cols = ["Land Area"]
#df_state_area.columns = [new_cols]
df_state_area
# Out:
#                        State Land Area (sq mi)
# 0                 California  155,779.03 (3rd)
# 1                      Texas  261,231.59 (2nd)
# 2                    Florida  53,624.55 (26th)
# 3                   New York  47,126.45 (30th)
# 4                   Illinois  55,518.76 (24th)
# 5               Pennsylvania  44,742.66 (32nd)
# 6                       Ohio  40,860.79 (35th)
# 7                    Georgia  57,513.37 (21st)
# 8             North Carolina  48,617.96 (29th)
# 9                   Michigan  56,538.85 (22nd)
# 10                New Jersey   7,354.08 (46th)
# 11                  Virginia  39,490.13 (36th)
# 12                Washington  66,455.49 (20th)
# 13             Massachusetts   7,800.03 (45th)
# 14                   Arizona  113,593.91 (6th)
# 15                   Indiana  35,826.02 (38th)
# 16                 Tennessee  41,234.92 (34th)
# 17                  Missouri  68,741.60 (18th)
# 18                  Maryland   9,707.38 (42nd)
# 19                 Wisconsin  54,157.76 (25th)
# 20                 Minnesota  79,626.59 (14th)
# 21                  Colorado  103,641.75 (8th)
# 22                   Alabama  50,645.39 (28th)
# 23            South Carolina  30,060.74 (40th)
# 24                 Louisiana  43,204.04 (33rd)
# 25                  Kentucky  39,486.27 (37th)
# 26                    Oregon  95,988.05 (10th)
# 27                  Oklahoma  68,594.88 (19th)
# 28               Connecticut   4,842.49 (48th)
# 29               Puerto Rico   3,423.95 (49th)
# 30                      Iowa  55,856.99 (23rd)
# 31               Mississippi  46,923.36 (31st)
# 32                  Arkansas  52,035.35 (27th)
# 33                      Utah  82,169.46 (12th)
# 34                    Kansas  81,758.64 (13th)
# 35                    Nevada  109,781.15 (7th)
# 36                New Mexico  121,298.19 (5th)
# 37                  Nebraska  76,824.26 (15th)
# 38             West Virginia  24,038.32 (41st)
# 39                     Idaho  82,643.20 (11th)
# 40                    Hawaii   6,422.81 (47th)
# 41                     Maine  30,842.99 (39th)
# 42             New Hampshire   8,952.55 (44th)
# 43              Rhode Island   1,033.98 (51st)
# 44                   Montana  145,545.78 (4th)
# 45                  Delaware   1,948.66 (50th)
# 46              South Dakota  75,811.13 (16th)
# 47              North Dakota  69,000.67 (17th)
# 48                    Alaska  570,640.61 (1st)
# 49      District Of Columbia      61.00 (56th)
# 50                   Vermont   9,216.64 (43rd)
# 51                   Wyoming   97,093.07 (9th)
# 52                      Guam     209.65 (52nd)
# 53            Virgin Islands     134.36 (54th)
# 54            American Samoa      76.45 (55th)
# 55  Northern Mariana Islands     182.24 (53rd)

# %%
##Remove the rankings
new_land_area = []
for x in df_state_area["Land Area (sq mi)"]:
    text = x.split()
    new_land_area.append(text[0])
      
df_state_area["Land Area (sq mi)"] = new_land_area
df_state_area


##Remove states that aren't in previous dataset:
list_not_states = []
for s,a in zip(df_state_area['State'], df_state_area["Land Area (sq mi)"]):
    if s not in States:
        print(s)
        df_state_area = df_state_area[df_state_area.State != s]

df_state_area
# Out:
# Puerto Rico
# District Of Columbia
# Guam
# Virgin Islands
# American Samoa
# Northern Mariana Islands
#              State Land Area (sq mi)
# 0       California        155,779.03
# 1            Texas        261,231.59
# 2          Florida         53,624.55
# 3         New York         47,126.45
# 4         Illinois         55,518.76
# 5     Pennsylvania         44,742.66
# 6             Ohio         40,860.79
# 7          Georgia         57,513.37
# 8   North Carolina         48,617.96
# 9         Michigan         56,538.85
# 10      New Jersey          7,354.08
# 11        Virginia         39,490.13
# 12      Washington         66,455.49
# 13   Massachusetts          7,800.03
# 14         Arizona        113,593.91
# 15         Indiana         35,826.02
# 16       Tennessee         41,234.92
# 17        Missouri         68,741.60
# 18        Maryland          9,707.38
# 19       Wisconsin         54,157.76
# 20       Minnesota         79,626.59
# 21        Colorado        103,641.75
# 22         Alabama         50,645.39
# 23  South Carolina         30,060.74
# 24       Louisiana         43,204.04
# 25        Kentucky         39,486.27
# 26          Oregon         95,988.05
# 27        Oklahoma         68,594.88
# 28     Connecticut          4,842.49
# 30            Iowa         55,856.99
# 31     Mississippi         46,923.36
# 32        Arkansas         52,035.35
# 33            Utah         82,169.46
# 34          Kansas         81,758.64
# 35          Nevada        109,781.15
# 36      New Mexico        121,298.19
# 37        Nebraska         76,824.26
# 38   West Virginia         24,038.32
# 39           Idaho         82,643.20
# 40          Hawaii          6,422.81
# 41           Maine         30,842.99
# 42   New Hampshire          8,952.55
# 43    Rhode Island          1,033.98
# 44         Montana        145,545.78
# 45        Delaware          1,948.66
# 46    South Dakota         75,811.13
# 47    North Dakota         69,000.67
# 48          Alaska        570,640.61
# 50         Vermont          9,216.64
# 51         Wyoming         97,093.07

# %%
#Divide CO2 emissions by state size: 
states = df_state_area['State']
areas = df_state_area['Land Area (sq mi)']
states_area_dict = dict(zip(states, areas))

CO2_div_area_states_dict = CO2_states_dict
#print(CO2_div_area_states_dict)

for state in States: 
    state_area = states_area_dict[state]
    state_area = float(state_area.replace(',', ''))
    CO2_div_area_states_dict[state] = float(CO2_div_area_states_dict[state]/state_area)
    
CO2_div_area_states_dict
# Out:
# {'Alabama': 9.603435792309375e-13,
#  'Alaska': 1.9263729179607674e-16,
#  'Arizona': 6.438350791881416e-14,
#  'Arkansas': 4.960614468489834e-13,
#  'California': 9.456881337803364e-14,
#  'Colorado': 8.34570903666912e-14,
#  'Connecticut': 3.135597104510015e-10,
#  'Delaware': 1.7447178909040154e-09,
#  'District of Columbia': 3.058482653904067,
#  'Florida': 1.4957757468594871e-12,
#  'Georgia': 7.432621976153217e-13,
#  'Hawaii': 7.019619654988456e-11,
#  'Idaho': 2.994259246932541e-14,
#  'Illinois': 1.3756547676404796e-12,
#  'Indiana': 4.522247021476614e-12,
#  'Iowa': 4.754564109501044e-13,
#  'Kansas': 1.2898316604497226e-13,
#  'Kentucky': 2.2630548543226925e-12,
#  'Louisiana': 2.52685458211409e-12,
#  'Maine': 5.747258077317978e-13,
#  'Maryland': 6.797885780690682e-11,
#  'Massachusetts': 1.361055445315644e-10,
#  'Michigan': 9.05013395215287e-13,
#  'Minnesota': 1.9015835098359913e-13,
#  'Mississippi': 6.26422694819077e-13,
#  'Missouri': 4.10451568776921e-13,
#  'Montana': 1.0502413732434117e-14,
#  'Nebraska': 1.1655582482106625e-13,
#  'Nevada': 2.848728769003193e-14,
#  'New Hampshire': 2.1188153471065772e-11,
#  'New Jersey': 2.8845875646388535e-10,
#  'New Mexico': 2.8364626531816504e-14,
#  'New York': 1.643060593506204e-12,
#  'North Carolina': 1.122703075296192e-12,
#  'North Dakota': 1.8068445917981783e-13,
#  'Ohio': 3.4352434259911156e-12,
#  'Oklahoma': 3.2800279263155317e-13,
#  'Oregon': 4.3562742452965394e-14,
#  'Pennsylvania': 2.7811836111676032e-12,
#  'Rhode Island': 9.754162804998427e-09,
#  'South Carolina': 2.7678197518779707e-12,
#  'South Dakota': 3.60178888483302e-14,
#  'Tennessee': 1.4973594908419194e-12,
#  'Texas': 3.511560679727417e-14,
#  'Utah': 1.1887015706090132e-13,
#  'Vermont': 7.635761801871848e-12,
#  'Virginia': 1.7118590124428468e-12,
#  'Washington': 2.468921713942428e-13,
#  'West Virginia': 7.28923527481353e-12,
#  'Wisconsin': 6.444245068340726e-13,
#  'Wyoming': 7.228474544934279e-14}

# %%
#Sort dictionary by CO2 emissions/state size:
sorted_CO2_div_area_states_dict = sorted(CO2_div_area_states_dict.items(), key=operator.itemgetter(1))
sorted_CO2_div_area_states_dict


#print(sorted_CO2_states_dict)
        
colors = []
sorted_states_by_CO2_div_area = [state[0] for state in sorted_CO2_div_area_states_dict]

for state in sorted_states_by_CO2_div_area: 
    if state_party_dict[state] == 'Republican':
        colors.append('red')
    else:
        colors.append('blue')

print(colors)
# Out:
# ['red', 'red', 'blue', 'blue', 'red', 'blue', 'red', 'blue', 'red', 'red', 'blue', 'blue', 'red', 'red', 'red', 'red', 'blue', 'blue', 'red', 'blue', 'red', 'red', 'blue', 'red', 'blue', 'blue', 'blue', 'red', 'blue', 'blue', 'blue', 'red', 'blue', 'red', 'red', 'blue', 'red', 'blue', 'red', 'red', 'red', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue']

# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt

fig_size = plt.rcParams["figure.figsize"]

fig_size[0] = 12
fig_size[1] = 9
plt.rcParams["figure.figsize"] = fig_size

States = []
CO2 = []

for state, co2 in sorted_CO2_div_area_states_dict: 
    if state != "District of Columbia":
        States.append(state)
        #CO2.append(co2)
        CO2.append(math.log(co2*(10**16)))

y_pos = np.arange(len(States))

plt.barh(y_pos, CO2, align='center', alpha=0.5, color=colors)
plt.yticks(y_pos, States)
plt.ylabel('CO2 Emissions (million metric tonnes) divided by state area size (sq miles) in 2014')
plt.title('U.S. State CO2 Emissions in 2014')

plt.show()

# %%
#Also might need to add a legend that states that red = republican and blue = democrat

# %% [markdown]
# ### Analysis: From the above graph, we see that there is no clear correlation between state political party affiliation and the amount of CO2 released by that state, even when we control for the state size.
#
# ### Instead, we will see if a state's political party affiliation has any correlation to the state population's awareness and perception of climate change.

# %%
states = df_YPCCC_2014_State_new["Statename"]
happenings = df_YPCCC_2014_State_new["happening"]
states_happening_dict = dict(zip(states, happenings))

sorted_states_happening_dict = sorted(states_happening_dict.items(), key=operator.itemgetter(1))
sorted_states_happening_dict
# Out:
# [('West Virginia', 54),
#  ('Wyoming', 55),
#  ('Alabama', 56),
#  ('Kentucky', 56),
#  ('North Dakota', 56),
#  ('Arkansas', 57),
#  ('Louisiana', 57),
#  ('Oklahoma', 57),
#  ('Idaho', 58),
#  ('Indiana', 58),
#  ('Kansas', 58),
#  ('Nebraska', 58),
#  ('Tennessee', 58),
#  ('Mississippi', 59),
#  ('Ohio', 59),
#  ('South Carolina', 59),
#  ('South Dakota', 59),
#  ('Iowa', 60),
#  ('Missouri', 60),
#  ('Montana', 60),
#  ('Utah', 60),
#  ('Michigan', 61),
#  ('New Hampshire', 61),
#  ('Wisconsin', 61),
#  ('Alaska', 62),
#  ('North Carolina', 62),
#  ('Pennsylvania', 62),
#  ('Georgia', 63),
#  ('Minnesota', 63),
#  ('Texas', 63),
#  ('Arizona', 64),
#  ('Florida', 64),
#  ('Maine', 64),
#  ('Nevada', 64),
#  ('Virginia', 64),
#  ('Delaware', 65),
#  ('Colorado', 66),
#  ('Connecticut', 66),
#  ('New Mexico', 66),
#  ('Rhode Island', 66),
#  ('Illinois', 67),
#  ('Oregon', 67),
#  ('Maryland', 68),
#  ('New Jersey', 68),
#  ('Vermont', 68),
#  ('Washington', 68),
#  ('Massachusetts', 69),
#  ('California', 70),
#  ('New York', 72),
#  ('Hawaii', 75),
#  ('District of Columbia', 81)]

# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt

fig_size = plt.rcParams["figure.figsize"]

fig_size[0] = 12
fig_size[1] = 9
plt.rcParams["figure.figsize"] = fig_size

States = []
Happening = []

for state, hap in sorted_states_happening_dict: 
    if state != "District of Columbia":
        States.append(state)
        Happening.append(hap)

y_pos = np.arange(len(States))

plt.barh(y_pos, Happening, align='center', alpha=0.5, color=colors)
plt.yticks(y_pos, States)
plt.xlabel('% of State Population that believes Global Warming is happening')
plt.ylabel('State')

plt.title('% of State Population that believes Global Warming is happening')

plt.show()
